# %% [markdown]
# # Práctico 2: Recomendación de videojuegos
#
# Autor: Mariano Zibecchi
# mzibecchi@gmail.com .
#
# La resolucion de la primer parte del practico, consiste en la definicion de una funcion __recomend_games_for_user__
#
# La funcion recibe como parametros el username, el modelo entrenado y la cantidad de recomendaciones que se desea recibir.
#
# Retorna como resultado una lista de juegos recomendados.
#
#
#
#
#
# En este práctico trabajaremos con un subconjunto de datos sobre [videojuegos de Steam](http://cseweb.ucsd.edu/~jmcauley/datasets.html#steam_data). Para facilitar un poco el práctico, se les dará el conjunto de datos previamente procesado. En este mismo notebook mostraremos el proceso de limpieza, para que quede registro del proceso (de todas maneras, por el tamaño de los datos no recomendamos que pierdan tiempo en el proceso salvo que lo consideren útil a fines personales).
#
# El conjunto de datos se basa en dos partes: lista de juegos (items), y lista de reviews de usuarios sobre distintos juegos. Este último, en su versión original es muy grande, (pesa 1.3GB), por lo que será solo una muestra del mismo sobre la que trabajarán.
#
# A diferencia del conjunto de datos de LastFM utilizados en el [Práctico 1](./practico1.ipynb), en este caso los datos no están particularmente pensados para un sistema de recomendación, por lo que requerirá de un poco más de trabajo general sobre el dataset.
#
# La idea es que, de manera similar al práctico anterior, realicen un sistema de recomendación. A diferencia del práctico anterior, este será un poco más completo y deberán hacer dos sistemas, uno que, dado un nombre de usuario le recomiende una lista de juegos, y otro que dado el título de un juego, recomiende una lista de juegos similares. Además, en este caso se requiere que el segundo sistema (el que recomienda juegos basado en el nombre de un juego en particular) haga uso de la información de contenido (i.e. o bien harán un filtrado basado en contenido o algo híbrido).

# %% [markdown]
# ## Obtención y limpieza del conjunto de datos
#
# El conjunto de datos originalmente se encuentra en archivos que deberían ser de formato "JSON". Sin embargo, en realidad es un archivo donde cada línea es un objeto de JSON. Hay un problema no obstante y es que las líneas están mal formateadas, dado que no respetan el estándar JSON de utilizar comillas dobles (**"**) y en su lugar utilizan comillas simples (**'**). Afortunadamente, se pueden evaluar como diccionarios de Python, lo cuál permite trabajarlos directamente.

# %% [markdown]
# ## Ejercicio 1: Análisis Exploratorio de Datos
#
# Ya teniendo los datos, podemos cargarlos y empezar con el práctico. Antes que nada vamos a hacer una exploración de los datos. Lo principal a tener en cuenta para este caso es que debemos identificar las variables con las que vamos a trabajar. A diferencia del práctico anterior, este conjunto de datos no está documentado, por lo que la exploración es necesaria para poder entender que cosas van a definir nuestro sistema de recomendación.

# %%
import pandas as pd

# %% [markdown]
# ### Características del conjunto de datos sobre videojuegos
#
# Las características del conjunto de datos de videojuegos tienen la información necesaria para hacer el "vector de contenido" utilizado en el segundo sistema de recomendación. Su tarea es hacer un análisis sobre dicho conjunto de datos y descartar aquella información redundante.

# %%
games_df = pd.read_json("./data/steam/games.json.gz")
games_df.sample(15)
# Out:
#                    publisher  \
# 30422           SCS Software
# 22251       Modern Dream Ltd
# 21015     Joe Censored Games
# 5219     Individual Software
# 29049               Microids
# 631    Kalypso Media Digital
# 29600             THQ Nordic
# 1275                 Ubisoft
# 27186    Black Cloud Studios
# 30367    Paradox Interactive
# 28989        Impromptu Games
# 29440                   None
# 4051                    None
# 18118                 Degica
# 10553         TOMAGameStudio
#
#                                                   genres  \
# 30422                                [Indie, Simulation]
# 22251                                    [Casual, Indie]
# 21015                                   [Action, Casual]
# 5219                                        [Accounting]
# 29049                         [Action, Adventure, Indie]
# 631                                           [Strategy]
# 29600  [Action, Indie, Racing, Simulation, Sports, Ea...
# 1275                                [Casual, Simulation]
# 27186              [Adventure, Indie, RPG, Early Access]
# 30367                                         [Strategy]
# 28989                                    [Casual, Indie]
# 29440                               [Casual, Simulation]
# 4051                                 [Action, Adventure]
# 18118        [Design &amp; Illustration, Web Publishing]
# 10553                                    [Action, Indie]
#
#                                             app_name  \
# 30422                         Euro Truck Simulator 2
# 22251                                         Savana
# 21015                                 Omega Reaction
# 5219                      Quicken Legal Business Pro
# 29049                                     Iron Storm
# 631                  Patrician IV: Rise of a Dynasty
# 29600                       Next Car Game: Wreckfest
# 1275     Rocksmith - Fall Out Boy - Thnks fr th Mmrs
# 27186                                After Reset RPG
# 30367                                         Impire
# 28989                     InFlux Original Soundtrack
# 29440   Rocksmith® 2014 – Boston - “Don’t Look Back”
# 4051                         Where Are They Now? Set
# 18118        RPG Maker MV - Elemental Dungeons Tiles
# 10553  Overdriven Reloaded - Special Edition Upgrade
#
#                                                title release_date  \
# 30422                         Euro Truck Simulator 2   2013-01-16
# 22251                                         Savana   2016-07-26
# 21015                                 Omega Reaction   2016-10-17
# 5219                      Quicken Legal Business Pro   2015-10-15
# 29049                                     Iron Storm   2002-10-25
# 631                  Patrician IV: Rise of a Dynasty   2011-04-11
# 29600                       Next Car Game: Wreckfest   2014-01-14
# 1275     Rocksmith - Fall Out Boy - Thnks fr th Mmrs   2013-02-05
# 27186                                After Reset RPG   2015-03-09
# 30367                                         Impire   2013-02-14
# 28989                     InFlux Original Soundtrack   2014-05-06
# 29440   Rocksmith® 2014 – Boston - “Don’t Look Back”   2014-03-04
# 4051                         Where Are They Now? Set   2015-07-23
# 18118        RPG Maker MV - Elemental Dungeons Tiles   2017-04-20
# 10553  Overdriven Reloaded - Special Edition Upgrade   2017-07-20
#
#                                                     tags  discount_price  \
# 30422  [Simulation, Driving, Open World, Realistic, R...             NaN
# 22251                     [Indie, Casual, Point & Click]             NaN
# 21015  [Action, Casual, Indie, Twin Stick Shooter, Co...             NaN
# 5219   [Software, Education, Great Soundtrack, Atmosp...             NaN
# 29049  [Action, Adventure, Indie, FPS, Alternate Hist...             NaN
# 631             [Strategy, Trading, Simulation, Economy]             NaN
# 29600  [Early Access, Racing, Destruction, Simulation...             NaN
# 1275                                [Casual, Simulation]             NaN
# 27186  [Early Access, RPG, Adventure, Indie, Post-apo...             NaN
# 30367           [Strategy, Fantasy, Villain Protagonist]             NaN
# 28989                                    [Indie, Casual]             NaN
# 29440                               [Casual, Simulation]             NaN
# 4051                                 [Action, Adventure]             NaN
# 18118            [Design & Illustration, Web Publishing]             NaN
# 10553  [Indie, Action, Bullet Hell, Arcade, Local Co-...             NaN
#
#                                                    specs  price  early_access  \
# 30422  [Single-player, Steam Achievements, Steam Trad...  19.99         False
# 22251                                    [Single-player]  14.99         False
# 21015        [Single-player, Partial Controller Support]   4.99         False
# 5219                                                None  44.99         False
# 29049                      [Single-player, Multi-player]   2.99         False
# 631    [Single-player, Multi-player, Co-op, Downloada...   9.99         False
# 29600  [Single-player, Multi-player, Online Multi-Pla...  39.99          True
# 1275   [Single-player, Shared/Split Screen, Downloada...   2.99         False
# 27186                                    [Single-player]  49.99          True
# 30367  [Single-player, Multi-player, Co-op, Steam Ach...  19.99         False
# 28989  [Single-player, Downloadable Content, Full con...   3.99         False
# 29440  [Single-player, Shared/Split Screen, Downloada...   2.99         False
# 4051   [Single-player, Downloadable Content, Steam Ac...   4.99         False
# 18118  [Downloadable Content, Steam Trading Cards, Pa...   9.99         False
# 10553  [Single-player, Local Multi-Player, Co-op, Loc...   None         False
#
#              id                      developer                sentiment  \
# 30422  227300.0                   SCS Software  Overwhelmingly Positive
# 22251  494970.0               Modern Dream Ltd           4 user reviews
# 21015  516520.0             Joe Censored Games           2 user reviews
# 5219   411350.0                           Nolo                     None
# 29049  296180.0                       Microids          Mostly Positive
# 631     57730.0           Gaming Minds Studios                    Mixed
# 29600  228380.0                        Bugbear                    Mixed
# 1275   222085.0        Ubisoft - San Francisco                     None
# 27186  335850.0            Black Cloud Studios                    Mixed
# 30367  202130.0               Cyanide Montreal                    Mixed
# 28989  278720.0                Jonathan Yandel                     None
# 29440  271442.0        Ubisoft - San Francisco                     None
# 4051   333811.0                  Acquire Corp.           3 user reviews
# 18118  580050.0  KADOKAWA,Yoji Ojima,Sherman3D           4 user reviews
# 10553  612000.0                 TOMAGameStudio                     None
#
#       metascore
# 30422        79
# 22251      None
# 21015      None
# 5219       None
# 29049        69
# 631          67
# 29600      None
# 1275       None
# 27186      None
# 30367        45
# 28989      None
# 29440      None
# 4051       None
# 18118      None
# 10553      None

# %%
len(games_df)
# Out:
# 32135

# %%
games_df.dtypes
# Out:
# publisher          object
# genres             object
# app_name           object
# title              object
# release_date       object
# tags               object
# discount_price    float64
# specs              object
# price              object
# early_access         bool
# id                float64
# developer          object
# sentiment          object
# metascore          object
# dtype: object

# %%
games_df['id'].isnull().sum()
# Out:
# 2

# %%
#games_df = games_df.dropna()
games_df[ games_df['id'].isnull() ]
# Out:
#                                                publisher               genres  \
# 74                                                  None                 None
# 30961  Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
#
#                                              app_name  \
# 74                                               None
# 30961  Batman: Arkham City - Game of the Year Edition
#
#                                                 title release_date  \
# 74                                               None         None
# 30961  Batman: Arkham City - Game of the Year Edition   2012-09-07
#
#                                                     tags  discount_price  \
# 74                                                  None           14.99
# 30961  [Action, Open World, Batman, Adventure, Stealt...             NaN
#
#                                                    specs  price  early_access  \
# 74                                                  None  19.99         False
# 30961  [Single-player, Steam Achievements, Steam Trad...  19.99         False
#
#        id                                   developer  \
# 74    NaN                                        None
# 30961 NaN  Rocksteady Studios,Feral Interactive (Mac)
#
#                      sentiment metascore
# 74                        None      None
# 30961  Overwhelmingly Positive        91

# %%
games_df = games_df.dropna (  subset=['id'] )

# %%
games_df[ games_df['id'].isnull() ]
# Out:
# Empty DataFrame
# Columns: [publisher, genres, app_name, title, release_date, tags, discount_price, specs, price, early_access, id, developer, sentiment, metascore]
# Index: []

# %%
games_df
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                  None                                               None
# ...                 ...                                                ...
# 32130   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32131            Sacada                          [Casual, Indie, Strategy]
# 32132      Laush Studio                        [Indie, Racing, Simulation]
# 32133          SIXNAILS                                    [Casual, Indie]
# 32134              None                                               None
#
#                        app_name                     title release_date  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty   2018-01-04
# 1                     Ironbound                 Ironbound   2018-01-04
# 2       Real Pool 3D - Poolians   Real Pool 3D - Poolians   2017-07-24
# 3                       弹炸人2222                   弹炸人2222   2017-12-07
# 4                 Log Challenge                      None         None
# ...                         ...                       ...          ...
# 32130            Colony On Mars            Colony On Mars   2018-01-04
# 32131  LOGistICAL: South Africa  LOGistICAL: South Africa   2018-01-04
# 32132             Russian Roads             Russian Roads   2018-01-04
# 32133       EXIT 2 - Directions       EXIT 2 - Directions   2017-09-02
# 32134               Maze Run VR                      None         None
#
#                                                     tags  discount_price  \
# 0          [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1      [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2      [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                            [Action, Adventure, Casual]            0.83
# 4                        [Action, Indie, Casual, Sports]            1.79
# ...                                                  ...             ...
# 32130              [Strategy, Indie, Casual, Simulation]            1.49
# 32131                          [Strategy, Indie, Casual]            4.24
# 32132                        [Indie, Simulation, Racing]            1.39
# 32133  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...             NaN
# 32134  [Early Access, Adventure, Indie, Action, Simul...             NaN
#
#                                                    specs         price  \
# 0                                        [Single-player]          4.99
# 1      [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2      [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                        [Single-player]          0.99
# 4      [Single-player, Full controller support, HTC V...          2.99
# ...                                                  ...           ...
# 32130                [Single-player, Steam Achievements]          1.99
# 32131  [Single-player, Steam Achievements, Steam Clou...          4.99
# 32132  [Single-player, Steam Achievements, Steam Trad...          1.99
# 32133   [Single-player, Steam Achievements, Steam Cloud]          4.99
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...          4.99
#
#        early_access        id                 developer        sentiment  \
# 0             False  761140.0                 Kotoshiro             None
# 1             False  643980.0          Secret Level SRL  Mostly Positive
# 2             False  670290.0              Poolians.com  Mostly Positive
# 3             False  767400.0                      彼岸领域             None
# 4             False  773570.0                      None             None
# ...             ...       ...                       ...              ...
# 32130         False  773640.0        Nikita "Ghost_RUS"             None
# 32131         False  733530.0                    Sacada             None
# 32132         False  610660.0  Laush Dmitriy Sergeevich             None
# 32133         False  658870.0             xropi,stev3ns   1 user reviews
# 32134          True  681550.0                      None         Positive
#
#       metascore
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# 32130      None
# 32131      None
# 32132      None
# 32133      None
# 32134      None
#
# [32133 rows x 14 columns]

# %%
games_df['id'] = games_df['id'].astype(int)

# %%
games_df.head()
# Out:
#           publisher                                             genres  \
# 0         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3              彼岸领域                        [Action, Adventure, Casual]
# 4              None                                               None
#
#                   app_name                    title release_date  \
# 0      Lost Summoner Kitty      Lost Summoner Kitty   2018-01-04
# 1                Ironbound                Ironbound   2018-01-04
# 2  Real Pool 3D - Poolians  Real Pool 3D - Poolians   2017-07-24
# 3                  弹炸人2222                  弹炸人2222   2017-12-07
# 4            Log Challenge                     None         None
#
#                                                 tags  discount_price  \
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2  [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                        [Action, Adventure, Casual]            0.83
# 4                    [Action, Indie, Casual, Sports]            1.79
#
#                                                specs         price  \
# 0                                    [Single-player]          4.99
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                    [Single-player]          0.99
# 4  [Single-player, Full controller support, HTC V...          2.99
#
#    early_access      id         developer        sentiment metascore
# 0         False  761140         Kotoshiro             None      None
# 1         False  643980  Secret Level SRL  Mostly Positive      None
# 2         False  670290      Poolians.com  Mostly Positive      None
# 3         False  767400              彼岸领域             None      None
# 4         False  773570              None             None      None

# %%
games_df.metascore.unique()
# Out:
# array([None, 96, 84, 80, 76, 70, 'NA', 69, 81, 75, 72, 66, 67, 77, 91, 89,
#        83, 61, 88, 65, 94, 57, 86, 87, 92, 79, 82, 58, 74, 85, 90, 68, 71,
#        60, 73, 59, 64, 54, 53, 78, 51, 44, 63, 38, 56, 49, 52, 62, 93, 48,
#        34, 95, 43, 55, 24, 46, 41, 20, 39, 45, 35, 47, 40, 36, 50, 32, 37,
#        33, 42, 27, 29, 30], dtype=object)

# %%
games_df.sentiment.unique()
# Out:
# array([None, 'Mostly Positive', 'Mixed', '1 user reviews',
#        '3 user reviews', '8 user reviews', 'Very Positive',
#        'Overwhelmingly Positive', '6 user reviews', '5 user reviews',
#        '2 user reviews', 'Very Negative', 'Positive', 'Mostly Negative',
#        '9 user reviews', 'Negative', '4 user reviews', '7 user reviews',
#        'Overwhelmingly Negative'], dtype=object)

# %% [markdown]
# ### Características del conjunto de datos de reviews
#
# Este será el conjunto de datos a utilizar para obtener información sobre los usuarios y su interacción con videojuegos. Como se puede observar no hay un rating explícito, sino uno implícito a calcular, que será parte de su trabajo (deberán descubrir que característica les puede dar información que puede ser equivalente a un rating).

# %%
reviews_df = pd.read_json("./data/steam/reviews.json.gz")
reviews_df.sample(15)
# Out:
#                   username  product_id  page_order  \
# 478742      Credit to Ding         440           3
# 111904           Big Smoke      382490           9
# 581076  ĐaИy \ Exams Yay /      409710           5
# 14722             MitziWho      270210           3
# 699125         Toxic Larva      434420           9
# 142218               Haduu      236450           8
# 515030             cvblade       48220           3
# 542526    professor_chaos_      291650           4
# 469105          nilssonbst         620           3
# 131097              ixurge      296050           4
# 240744                S00P       71000           7
# 317916              Cheese      270050           1
# 466005    TheBiggestTicket      292730           9
# 279192        InvisibleJim      247870           2
# 447003      blahblahsmokes      268910           7
#
#                                                      text   hours  products  \
# 478742  I like the part where i get bodyshot by a ftp ...  1723.1     155.0
# 111904                                      Too addicting     4.2      30.0
# 581076  Already made a review for Bioshock several yea...     1.6      89.0
# 14722   I love this game you can play songs from your ...    19.1      95.0
# 699125                        I don't recommend this game     3.4     561.0
# 142218  BEAST GAME 1000000 HIGH SCORE GET ON MY LEVEL ...     0.3     109.0
# 515030  Better then 5, Leaps and bounds better than 4,...     8.2     181.0
# 542526  This game has so much potential, but the comba...    11.6      82.0
# 469105  ***REVIEW FOR MAC***\nModel\nMac Air, Mid-2012...     2.2     142.0
# 131097                played 15 minutes.\nbored to death.     0.2     829.0
# 240744  To SOME people I would recommend it. It's not ...   118.1     247.0
# 317916               Fun, Impossibe and very addicting <3    11.9     138.0
# 466005  People love to hate on this game but it's very...   607.5      17.0
# 279192  This game was badly overhyped by a press that ...     0.3     772.0
# 447003  look i do reccomend this. BUTT! there is this ...     4.2      30.0
#
#              date  early_access  page compensation  found_funny       user_id
# 478742 2016-03-26         False  9039         None          1.0           NaN
# 111904 2015-09-01         False   182         None          NaN  7.656120e+16
# 581076 2017-11-27         False    20         None          NaN           NaN
# 14722  2014-03-15          True   185         None          1.0  7.656120e+16
# 699125 2017-01-08         False    13         None          NaN  7.656120e+16
# 142218 2014-09-22         False   287         None          NaN  7.656120e+16
# 515030 2015-01-26         False   117         None          NaN  7.656120e+16
# 542526 2016-01-15         False   302         None          NaN  7.656120e+16
# 469105 2015-01-30         False  3142         None          NaN           NaN
# 131097 2016-01-22         False     8         None          NaN           NaN
# 240744 2016-02-12         False     3         None          NaN  7.656120e+16
# 317916 2014-07-19         False    29         None          NaN           NaN
# 466005 2017-10-08         False    37         None          NaN  7.656120e+16
# 279192 2014-11-29         False    11         None          NaN           NaN
# 447003 2017-12-27         False    82         None          NaN  7.656120e+16

# %% [markdown]
# Descripcion del Dataset:
# * hours - horas jugadas antes de emitir el review
# * early_access - si se trata de una version early access del producto
# **Early Access is not meant to be a form of pre-purchase, but a tool to get your game in front of Steam users and gather feedback while finishing your game. Early Access titles must deliver a playable game or usable software to the customer at the time of purchase, while pre-purchase games are delivered at a future date.**
# * found_funny - otros usuarios encontraron el review divertido
# * compensation -
# * products - indica los diferentes juegos q tiene la cuenta en su libreria

# %%
user = 'TheDoofMoments'
reviews_df[ reviews_df['username'] == user ]
# Out:
#               username  product_id  page_order              text  hours  \
# 127491  TheDoofMoments      200210           0  I like this game  625.3
#
#         products       date  early_access  page compensation  found_funny  \
# 127491      65.0 2017-07-02         False   150         None          NaN
#
#         user_id
# 127491      NaN

# %%
user = 'SPejsMan'
reviews_df[ reviews_df['username'] == user ]
# Out:
#        username  product_id  page_order                       text  hours  \
# 0      SPejsMan      227940           0  Just one word... Balance!   23.0
# 87241  SPejsMan      282070           7      It is good to be bad.   13.8
#
#        products       date  early_access  page compensation  found_funny  \
# 0          92.0 2015-02-25          True  3159         None          NaN
# 87241      92.0 2016-11-26         False   459         None          NaN
#
#        user_id
# 0          NaN
# 87241      NaN

# %%
user = 'Agron Bulchard-Chataeu'
reviews_df[ reviews_df['username'] == user ]
# Out:
# Empty DataFrame
# Columns: [username, product_id, page_order, text, hours, products, date, early_access, page, compensation, found_funny, user_id]
# Index: []

# %% [markdown]
# Veamos un juego en particular __Total War™: ROME II - Emperor Edition__
# y los reviews que tuvo...

# %%
games_df[ games_df ['id'] == 214950 ]
# Out:
#       publisher      genres                               app_name  \
# 30024      SEGA  [Strategy]  Total War™: ROME II - Emperor Edition
#
#                                        title release_date  \
# 30024  Total War™: ROME II - Emperor Edition   2013-09-02
#
#                                                     tags  discount_price  \
# 30024  [Strategy, Historical, Turn-Based Strategy, Gr...             NaN
#
#                                                    specs  price  early_access  \
# 30024  [Single-player, Multi-player, Steam Trading Ca...  59.95         False
#
#            id          developer        sentiment metascore
# 30024  214950  Creative Assembly  Mostly Positive        76

# %%
roma_reviews_df = reviews_df [ reviews_df['product_id'] == 214950]
roma_reviews_df
# Out:
#                        username  product_id  page_order  \
# 7                 CaptainPlanet      214950           1
# 1449             Ciddie Fobbler      214950           5
# 1896               turtleownage      214950           1
# 2259            battlegalactika      214950           8
# 2468          Terminally Chill™      214950           8
# ...                         ...         ...         ...
# 697932             sosacharly30      214950           1
# 698520                  DrFDisK      214950           1
# 699106                  AMP2533      214950           1
# 699216  Adjusted for Infeeltion      214950           4
# 699404              Lord Cadwan      214950           1
#
#                                                      text  hours  products  \
# 7       If you like slaughtering in the name of Rome, ...  203.3     274.0
# 1449                    Does ok at the things that are ok  130.6     115.0
# 1896    Super fun, battles are epic and a treat to wat...    7.1      40.0
# 2259    The combat is simply broken\nIt doesnt feel li...   76.9       5.0
# 2468    Stiltzkin: are you high\nStiltzkin: youve been...   43.0      17.0
# ...                                                   ...    ...       ...
# 697932  WORSE♥♥♥♥♥♥I HAVE EVER PLAYED BY CA I SWEAR SL...  805.1      23.0
# 698520  Worse than I expected. Still not a finished ga...    6.1     265.0
# 699106  I personally like this game but after having s...   96.4      95.0
# 699216  A great strategy game built on the reliable to...   70.8     170.0
# 699404  Good game with incredibly enjoyable battle, pa...  236.6       7.0
#
#              date  early_access  page compensation  found_funny       user_id
# 7      2016-10-27         False   285         None          NaN  7.656120e+16
# 1449   2015-08-08         False   621         None          NaN           NaN
# 1896   2017-10-25         False    78         None          NaN  7.656120e+16
# 2259   2017-05-12         False   153         None          NaN  7.656120e+16
# 2468   2015-02-15         False   816         None         10.0           NaN
# ...           ...           ...   ...          ...          ...           ...
# 697932 2014-08-01         False  1195         None          NaN  7.656120e+16
# 698520 2015-06-28         False   664         None          NaN           NaN
# 699106 2016-02-10         False   467         None          NaN           NaN
# 699216 2016-11-23         False   266         None          NaN           NaN
# 699404 2015-05-21         False   713         None          1.0  7.656120e+16
#
# [1254 rows x 12 columns]

# %%
user = 'sosacharly30'
reviews_df[ reviews_df['username'] == user ].text
# Out:
# 697932    WORSE♥♥♥♥♥♥I HAVE EVER PLAYED BY CA I SWEAR SL...
# Name: text, dtype: object

# %%
roma_reviews_df.username.value_counts()
# Out:
# Caesar                   2
# bart.es                  2
# Fuckmuffin               2
# Sitout.AmnesiacGaming    2
# Gutenisse                2
#                         ..
# Anonymous                1
# jhtheone13030            1
# bigh100                  1
# Tobias Fünke             1
# AMP2533                  1
# Name: username, Length: 1228, dtype: int64

# %%
user = 'Caesar'
roma_reviews_df[ roma_reviews_df['username'] == user ]
# Out:
#        username  product_id  page_order  \
# 209383   Caesar      214950           4
# 647322   Caesar      214950           4
#
#                                                      text  hours  products  \
# 209383                            can't compare to rome 1  686.2      36.0
# 647322  I love everything simply because of the mod ba...  495.3      86.0
#
#              date  early_access  page compensation  found_funny  user_id
# 209383 2014-09-29         False  1081         None          NaN      NaN
# 647322 2014-09-20         False  1117         None          NaN      NaN

# %%
len(reviews_df)
# Out:
# 700000

# %%
reviews_df.describe()
# Out:
#           product_id     page_order          hours       products  \
# count  700000.000000  700000.000000  697558.000000  698708.000000
# mean   251130.840463       4.485711     111.498797     236.192551
# std    150044.054746       2.875279     385.359458     485.337170
# min        10.000000       0.000000       0.000000       1.000000
# 25%    203770.000000       2.000000       4.000000      45.000000
# 50%    252490.000000       4.000000      15.200000     110.000000
# 75%    346110.000000       7.000000      59.300000     246.000000
# max    773900.000000       9.000000   18570.900000   12832.000000
#
#                 page    found_funny       user_id
# count  700000.000000  107375.000000  2.855870e+05
# mean      890.908570       7.738217  7.656120e+16
# std      1923.769739      71.931147  1.009730e+08
# min         1.000000       1.000000  7.656120e+16
# 25%        52.000000       1.000000  7.656120e+16
# 50%       237.000000       1.000000  7.656120e+16
# 75%       828.000000       2.000000  7.656120e+16
# max     18371.000000    6956.000000  7.656120e+16

# %%
reviews_df.dtypes
# Out:
# username                object
# product_id               int64
# page_order               int64
# text                    object
# hours                  float64
# products               float64
# date            datetime64[ns]
# early_access              bool
# page                     int64
# compensation            object
# found_funny            float64
# user_id                float64
# dtype: object

# %%
reviews_df.compensation.value_counts()
# Out:
# Product received for free    13286
# Name: compensation, dtype: int64

# %% [markdown]
# #### Juegos con mas reviews

# %%
reviews_df.groupby('product_id').agg({'page_order':'count'}).sort_values('page_order', ascending=False).head()
# Out:
#             page_order
# product_id
# 440              16570
# 252490            9161
# 49520             6349
# 377160            6335
# 271590            5239

# %%
reviews_df.found_funny.value_counts()
# Out:
# 1.0       62816
# 2.0       17737
# 3.0        7511
# 4.0        4259
# 5.0        2585
#           ...
# 285.0         1
# 1153.0        1
# 1170.0        1
# 432.0         1
# 253.0         1
# Name: found_funny, Length: 589, dtype: int64

# %% [markdown]
# ## Ejercicio 2 - Sistema de Recomendación Basado en Usuarios
#
# Este sistema de recomendación deberá entrenar un algoritmo y desarrollar una interfaz que, dado un usuario, le devuelva una lista con los juegos más recomendados.

# %%
#cant_horas_user = reviews_df.groupby(['username']).agg( cant_horas = pd.NamedAgg(column='hours', aggfunc=sum))
cant_horas_user = reviews_df.groupby(['username']).hours.sum()
cant_horas_user
# Out:
# username
# !                      123.3
# !             *          5.6
# ! 5tryx                  0.9
# ! DeadlyDeal !           6.3
# ! Indelible             58.3
#                        ...
# 󰀈Spectra󰀈                4.9
# 󰀍 loopuleasa 󰀍          96.9
# 󰀓Oxymoronicphalanx󰀓      0.4
# 󰀕СЭНС󰀕                  21.1
# 󰀗 Lolicage               7.5
# Name: hours, Length: 495383, dtype: float64

# %%
reviews_df['cant_horas_user'] = reviews_df['username'].apply(lambda x: cant_horas_user[x] 
                                                          if x in cant_horas_user else -1)

# %%
reviews_df[ reviews_df['username'] == 'Caesar' ]
# Out:
#        username  product_id  page_order  \
# 77242    Caesar      221100           5
# 195973   Caesar      327070           0
# 209383   Caesar      214950           4
# 235587   Caesar      219640           8
# 275411   Caesar      204100           0
# 285946   Caesar      441790           0
# 298652   Caesar      588430           7
# 349061   Caesar      223850           3
# 397510   Caesar      582660           8
# 408255   Caesar      204300           8
# 462667   Caesar       34030           4
# 495692   Caesar      333950           5
# 534115   Caesar      447020           4
# 544580   Caesar      468250           0
# 577033   Caesar      269810           8
# 646557   Caesar      473690           9
# 647322   Caesar      214950           4
# 676969   Caesar      239820           7
#
#                                                      text  hours  products  \
# 77242                             Forever "Early Access".   67.0      21.0
# 195973  Game's unplayable (I know it's EA, but still) ...    1.3     280.0
# 209383                            can't compare to rome 1  686.2      36.0
# 235587            Total loss of money,time and resources.    5.1      88.0
# 275411  Good pc port I can max settings @ 1080p with 2...    9.5      48.0
# 285946  For an EA this game is fun. Graphics are amazi...   81.8      37.0
# 298652                                        pay to win.    3.3      76.0
# 349061               The ultimate pay to win game.\n10/10   19.3     183.0
# 397510  Incredible design and textures. Game has great...  120.5      92.0
# 408255  Awesomenauts is a side-scrolling 3v3 DOTA-styl...  100.3      76.0
# 462667  Amazing game, nice touch on units and the game...   73.2       8.0
# 495692  Could be awesome, once done..\nRight now it's ...    3.8     280.0
# 534115  Vehicle controls are weird, especially steerin...   11.0      98.0
# 544580                                          Good game   10.7      16.0
# 577033  Played this game from start to finish in one r...    1.6     949.0
# 646557  Still early in the game but combat and levelin...   13.6     130.0
# 647322  I love everything simply because of the mod ba...  495.3      86.0
# 676969  I really liked it. It is fun until you unlock ...   19.8      11.0
#
#              date  early_access  page compensation  found_funny       user_id  \
# 77242  2016-02-01          True  2517         None          NaN  7.656120e+16
# 195973 2016-07-08          True    73         None          NaN           NaN
# 209383 2014-09-29         False  1081         None          NaN           NaN
# 235587 2017-03-27         False   290         None          NaN  7.656120e+16
# 275411 2015-01-31         False   420         None          NaN           NaN
# 285946 2016-04-30          True    46         None          NaN           NaN
# 298652 2017-06-20         False   249         None          NaN           NaN
# 349061 2017-04-06         False    18         None          3.0           NaN
# 397510 2017-07-04         False   346         None          NaN  7.656120e+16
# 408255 2015-05-14         False   545         None          NaN           NaN
# 462667 2017-11-26         False    11         None          NaN  7.656120e+16
# 495692 2015-03-17          True   178         None          NaN           NaN
# 534115 2018-01-02         False     3         None          NaN  7.656120e+16
# 544580 2017-06-07         False    13         None          NaN  7.656120e+16
# 577033 2015-05-03         False     9         None          NaN           NaN
# 646557 2017-08-29         False   473         None          NaN  7.656120e+16
# 647322 2014-09-20         False  1117         None          NaN           NaN
# 676969 2016-07-03         False   320         None          NaN  7.656120e+16
#
#         cant_horas_user
# 77242            1723.3
# 195973           1723.3
# 209383           1723.3
# 235587           1723.3
# 275411           1723.3
# 285946           1723.3
# 298652           1723.3
# 349061           1723.3
# 397510           1723.3
# 408255           1723.3
# 462667           1723.3
# 495692           1723.3
# 534115           1723.3
# 544580           1723.3
# 577033           1723.3
# 646557           1723.3
# 647322           1723.3
# 676969           1723.3

# %%
reviews_df['rating'] = reviews_df['hours'] / reviews_df['cant_horas_user']

# %%
reviews_df[ reviews_df['username'] == 'Caesar' ]
# Out:
#        username  product_id  page_order  \
# 77242    Caesar      221100           5
# 195973   Caesar      327070           0
# 209383   Caesar      214950           4
# 235587   Caesar      219640           8
# 275411   Caesar      204100           0
# 285946   Caesar      441790           0
# 298652   Caesar      588430           7
# 349061   Caesar      223850           3
# 397510   Caesar      582660           8
# 408255   Caesar      204300           8
# 462667   Caesar       34030           4
# 495692   Caesar      333950           5
# 534115   Caesar      447020           4
# 544580   Caesar      468250           0
# 577033   Caesar      269810           8
# 646557   Caesar      473690           9
# 647322   Caesar      214950           4
# 676969   Caesar      239820           7
#
#                                                      text  hours  products  \
# 77242                             Forever "Early Access".   67.0      21.0
# 195973  Game's unplayable (I know it's EA, but still) ...    1.3     280.0
# 209383                            can't compare to rome 1  686.2      36.0
# 235587            Total loss of money,time and resources.    5.1      88.0
# 275411  Good pc port I can max settings @ 1080p with 2...    9.5      48.0
# 285946  For an EA this game is fun. Graphics are amazi...   81.8      37.0
# 298652                                        pay to win.    3.3      76.0
# 349061               The ultimate pay to win game.\n10/10   19.3     183.0
# 397510  Incredible design and textures. Game has great...  120.5      92.0
# 408255  Awesomenauts is a side-scrolling 3v3 DOTA-styl...  100.3      76.0
# 462667  Amazing game, nice touch on units and the game...   73.2       8.0
# 495692  Could be awesome, once done..\nRight now it's ...    3.8     280.0
# 534115  Vehicle controls are weird, especially steerin...   11.0      98.0
# 544580                                          Good game   10.7      16.0
# 577033  Played this game from start to finish in one r...    1.6     949.0
# 646557  Still early in the game but combat and levelin...   13.6     130.0
# 647322  I love everything simply because of the mod ba...  495.3      86.0
# 676969  I really liked it. It is fun until you unlock ...   19.8      11.0
#
#              date  early_access  page compensation  found_funny       user_id  \
# 77242  2016-02-01          True  2517         None          NaN  7.656120e+16
# 195973 2016-07-08          True    73         None          NaN           NaN
# 209383 2014-09-29         False  1081         None          NaN           NaN
# 235587 2017-03-27         False   290         None          NaN  7.656120e+16
# 275411 2015-01-31         False   420         None          NaN           NaN
# 285946 2016-04-30          True    46         None          NaN           NaN
# 298652 2017-06-20         False   249         None          NaN           NaN
# 349061 2017-04-06         False    18         None          3.0           NaN
# 397510 2017-07-04         False   346         None          NaN  7.656120e+16
# 408255 2015-05-14         False   545         None          NaN           NaN
# 462667 2017-11-26         False    11         None          NaN  7.656120e+16
# 495692 2015-03-17          True   178         None          NaN           NaN
# 534115 2018-01-02         False     3         None          NaN  7.656120e+16
# 544580 2017-06-07         False    13         None          NaN  7.656120e+16
# 577033 2015-05-03         False     9         None          NaN           NaN
# 646557 2017-08-29         False   473         None          NaN  7.656120e+16
# 647322 2014-09-20         False  1117         None          NaN           NaN
# 676969 2016-07-03         False   320         None          NaN  7.656120e+16
#
#         cant_horas_user    rating
# 77242            1723.3  0.038879
# 195973           1723.3  0.000754
# 209383           1723.3  0.398190
# 235587           1723.3  0.002959
# 275411           1723.3  0.005513
# 285946           1723.3  0.047467
# 298652           1723.3  0.001915
# 349061           1723.3  0.011199
# 397510           1723.3  0.069924
# 408255           1723.3  0.058202
# 462667           1723.3  0.042477
# 495692           1723.3  0.002205
# 534115           1723.3  0.006383
# 544580           1723.3  0.006209
# 577033           1723.3  0.000928
# 646557           1723.3  0.007892
# 647322           1723.3  0.287414
# 676969           1723.3  0.011490

# %% [markdown]
# Verificamos que no hayan quedado valores nulos en el rating que calculamos

# %%
reviews_df['rating'].isnull().sum()
# Out:
# 2616

# %% [markdown]
# Vamos a reemplazar los nulos por 0

# %%
import numpy as np

reviews_df['rating'] = reviews_df['rating'].replace(to_replace = np.nan, value =0 )

# %%
reviews_df['rating'].isnull().sum()
# Out:
# 0

# %%
import pandas as pd
import seaborn as sns

ax = sns.distplot(reviews_df['rating'])

# %% [markdown]
# ### Armamos la matriz de usuario-contenido

# %%
muc_df = reviews_df[ ['username','product_id','rating'] ]
muc_df.head()
# Out:
#       username  product_id    rating
# 0     SPejsMan      227940  0.625000
# 1    Spodermen      270170  0.308176
# 2         josh       41700  0.052637
# 3    Sammyrism      332310  0.054054
# 4  moonmirroir      303210  1.000000

# %%
len(reviews_df)
# Out:
# 700000

# %%
len(muc_df)
# Out:
# 700000

# %%
muc_df = muc_df.sample(5000)

# %%
muc_df.head()
# Out:
#                              username  product_id    rating
# 444663                       S-Zachel      428750  1.000000
# 468004                         igrvak      427520  1.000000
# 399901              Johnny Hammerstix      346110  0.920511
# 135067                           Tord      232430  1.000000
# 349192  King Ling Ming Chigga Ting II        8930  0.952644

# %%
from surprise import Dataset, Reader, KNNWithMeans, BaselineOnly
from surprise.accuracy import rmse
from surprise.model_selection import cross_validate, train_test_split

# %%
#ratings_train, ratings_test = train_test_split(ratings, test_size=0.2)

# model = KNNWithMeans(k=3).fit( ratings.build_full_trainset() )

reader = Reader(rating_scale=(muc_df.rating.min(), muc_df.rating.max()))

ratings = Dataset.load_from_df( muc_df[["username", "product_id", "rating"]], reader)

trainset = ratings.build_full_trainset()
                               
bsl_options = {'method': 'als',
               'n_epochs': 5,
               'reg_u': 12,
               'reg_i': 5
               }
model = BaselineOnly(bsl_options=bsl_options)

model.fit( trainset )
# Out:
# Estimating biases using als...

# %% [markdown]
# ### Trabajamos en la funcion de recomendacion

# %%
from collections import defaultdict

def get_top_n(predictions, n=10):
    '''Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    '''

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
# Predict ratings for all pairs (u, i) that are NOT in the training set.

testset = trainset.build_anti_testset()
predictions = model.test(testset)

top_n = get_top_n(predictions, n=10)

# Print the recommended items for each user
for uid, user_ratings in top_n.items():
    print(uid, [iid for (iid, _) in user_ratings])
# Out:
# S-Zachel [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# igrvak [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Johnny Hammerstix [346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# Tord [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# King Ling Ming Chigga Ting II [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# yourmom260 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# UNLOLS [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ❄Ｓｅｒｅｎｉｔｙ❄ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dropthegun [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# OFFINE [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Jeton [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# fallunlight [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Logicbeatsreason [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# tiiM-zlatnekajle- [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sir 73 ChrOMozones [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Jonezy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Schlubotipelto [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Losasaurus [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dredda888888 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ratcharmer [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# shoggofu [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# weirdkid155 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Yveltal [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Frebresio [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# king-of-sass [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dubble [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# gorgeo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Radikal℠ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# KroeboCop [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# electricdrip [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sad Sunn [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# x2Madda [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# afterburner1987 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# shadilay [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Kaeltis [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Subject16 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Gamer [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# joshypereira13 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Darkurvar [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Metalmaniacal [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sidetrackx [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Youpiao [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Omegadom [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# anand.gaston [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ironhide69 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 48700, 440]
# nut buster [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [TGG]DeVapeR [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nitro [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# megadandrum [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# awsome dogy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# {>George<} [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [P] Olm [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Average Joe [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Monox [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sanguis3k [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hoogles [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Awesometwo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# MaloJewell [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Poobah [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Casca17 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 316010, 48700, 440]
# ᏕᏂᎥᏒᎧ | skinsjar.com [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# WoodsZebra63 The Big Rig [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Queerius [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# JaimeModafocaTytysMcSwag69 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# the spookiest of logos [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# *Jacobson* [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sketch [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 7.62x39 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Snax [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [HK]⚡FatSquirrel⚡ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# *****idx [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# StarDebris [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Joel McFergendergen [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# FaZe KQLY [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Craptor Squeak [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# alex [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Arceles [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Kung Fu Kenny [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Baron von Arthur [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# deborahzzzzz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# The_Indolent [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tiwaz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# GODrums [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Naithn [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Kit [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Csnipes [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hangover [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 440]
# GManLegendary [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# President of the Trap [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sigmuletz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hoss0223 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Zizo008 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Klimadzu [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ASUS ROG Karnal [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# BONELESS PIZZA [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# borus [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Cybapasu [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Moosey Fate [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# RootinTootinVladimirPutin [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# beastmode_salsa [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# adamc55 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ₪ VirusCĴ //_^)” [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tsounami [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# pook99 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# whjte [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# warlorddc [346110, 346900, 440900, 231430, 363970, 4000, 214950, 316010, 48700, 440]
# (economy) [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# eF eN [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# harkov311 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# scoutbrandon [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# M A T T 1 Z M [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Boggins [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Re Roley [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# spooky driver croc [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Cyphre [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# The Dude [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# CRABST3R [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# sandwich [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sarcasmouse [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Abstract Apparition [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# GarryColeMan (Shalev) [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# boydwazup [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Thranor [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Acehunter [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dr. Schnozzbery [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# YOUR MOM THE BIG SEXS [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SamEffect [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# stalkiller [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# holla at me [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# freshestpaint [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# No Lives Matter [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Durrrr [346110, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# Randy Bobandy's Cheeseburger Gut [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Rick [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nika [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# aclark4278 [346110, 346900, 440900, 231430, 363970, 214950, 226860, 316010, 48700, 440]
# xXMohammadXx [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mookzs [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# squidman [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Zaego [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# kindofgaming [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Depressed Mong [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# weeb [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# mountainmage [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# TheSlayer [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Willzile1 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# OzzyMan [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# CheeSe [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ne[a]era [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# gcopsey [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# WA3 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Kranbert [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# guitarguy308 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Buurt [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Shem [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Lizzy Meowchuu~ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Peachthief [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# TWDGTAETS2 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# DeadSilent [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# GotsNoTime [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Goddamn Van Damme Is The Man. [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Issa Knife [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sprite Brite [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Chicken Dude [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 440]
# GrayScale [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# machinajason [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Scoots [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 爪尺ち口爪モれ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# salomon90 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Monjac [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Alpha [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Rural Juror [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# fuze [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ImHannezz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [FOR]mica [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Plüschtier [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Treycombat [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ShXIII [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SLAUGHTERKULT [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Arsalan [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# | TurdyTree | Yengyeng [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Portue [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hazen [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Imitae [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Allerawia [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# YUNGLIMP [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hudson [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hammer My Wood [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sir Moag [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# zylvanbane [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# PutridMeat [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# KingPin™ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Red [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# bug [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nea [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ginphozez [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ye man [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# HarRy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [ReAp]Neko Vamps🦇 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Echo / Sound Test Service. [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Vayl ♥ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Xthreeo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Moobs [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# (FMG) MADLOO87 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Jonah ☯ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SweeTARTS Candy® [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ƬHЄ MƠƦƦƖƓƛƝ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sutr [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# JAD [ . . . is a programmer D: ] [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# trifecta1823 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Cro [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Teedo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Zet [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [GS7N] hex [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Kidpanda [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# TangoRango [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# laxoc001 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Scrawler [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Chinu [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# skylar [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# .krouded [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ANN3X [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Leo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# NASTY CORNDOG [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ruddigore [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# mswaggor [346110, 346900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# Not Even Klaus [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hanuu haista fgt 2016 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 1Shot10Kill [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Stonx [346110, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# Derry.VØID [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# PookPunk [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# PROMETOR12 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# HOGuru [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# HAMBONE [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Stanthrax [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# FallenNephilim [346110, 346900, 440900, 231430, 363970, 4000, 214950, 316010, 48700, 440]
# Mold [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tesco Overlord [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# AgentOrangeUK [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Günther Lauch [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Rebecca [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Carp [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Moxonabi [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# tyker+ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ro-mal [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# T E K A S H I 6 I X 9 I N E [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mr. Mouse [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Raltz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tosh [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# snappyhurdle [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Señor Jangles [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ScammersSuck [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# unrealbrandonhine [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dcsmall [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# One in yah dome [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# shekerev [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hezar5166 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# STIXI [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# CaptainSpartan [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# BatLMage [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# End my Payne [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Whiterabbit-uk [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# MrSalmon [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Gandohar [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# subarucuck [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# eXONIk. [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Valculrik [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# J-Roc [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Rednextrz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# StarWolf [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 乇乂ㄒ尺卂 ㄒ卄丨匚匚 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nykos [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nero [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Roger Wilco [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dr Dax Waxman [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Invalid Villain [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Armesi [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 01010001 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tzuyu CSGO-Skins.com [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Master Togo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Blakestarr1 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# shepardfikson [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# LiquidWater [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# zebramason [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# DANNY [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Piper the sniper [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Fletchmustdie [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nighthunter87 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Deldenary [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hollows21 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Beridok [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# FER9IE [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Rectal Spray [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# The Gemsbok [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# bbambii [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# L Plays Gaming [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# fraxyl [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Bluepeez [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# an accident [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# TheTodd [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# IamValhalla [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SonicBoom13561 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Stewartsaurus -88- [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SpicedBeefers [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ExuLittleSkull [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# cantplayanything [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Suleiman the Magnificent [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# BirdyBirdyNight [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Shipwrecked [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# aabughazaleh [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Alpha Bravo Fruitcake [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Cupcake [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# The_Vakarian [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Marcel [346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# Pako [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ESToomere [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# maibigbutt [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# RazorBees & PaperClips [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Red Lobster [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 디포르 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# dypstyk [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Salarn [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# syrito [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Crazy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Rick Sanchez [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Senpai Sixxy [346110, 346900, 440900, 231430, 363970, 214950, 226860, 316010, 48700, 440]
# Archetype-000 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SAB [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Cowboy Flipflop [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Alli_a899_Alex [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# haruyoshida91 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Trip J [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# db [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SpaceCouncil [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 👾 🅼 🅰❎ツ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ZarquonReturns [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# PrehistoricAstronaut [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# GamerZak32 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# neonray.pk8 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ManBearPig [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Drakensson [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# theindiegeek [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# LIMPDICK [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Prat [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sorcha [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Magnum Von Evilton [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sad Dio [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# BaneRaven [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# サイモンサリフ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Xaphnir [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mini 777 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hammerspace48 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Boomstorm [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mr. Robot [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# roboczar [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Purple High [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# {BZA}xXHEROXx [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Roxy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Peake [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Rayden Belmont [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# lolicol And Snipah Plus [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [NG+]RedDragon91 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ThankYouKarl [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nurdbot [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Anjesen [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Who would have thought [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# leyland [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# MlaG Shunwon [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tom [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Fr0zenbear [346110, 346900, 440900, 231430, 4000, 214950, 226860, 316010, 48700, 440]
# Brian [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Angewidert. [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nearpai [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# PUMPANG PUMPANG [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# mickbell [346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# Goram [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Deergon [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Oasis [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Јохн | John [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# plmkoo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# LewwyButton♛ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Christian Gamer Jolee [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# FelixTheTrap ❤ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# data7of9 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Onyx [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# crez_33 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Josh_Wolf [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Game [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ungol [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# archeolog108 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# boob [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# FudoAkira [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# farbap v. 1.2.9 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Blahhaman [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# BichaelMay [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Jeak Ol [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ceigar [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Surgeon [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ,=,e Senior [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Aaruman [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# placid walrus [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Deus [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# chato6611 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Wolfe [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mustache_Man [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Snow16 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# cuma.elp [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# myeeah7 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Counsel [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Wiggles [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# GENEPOOL [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Smug Anime Girl [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# noahbeeri [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# romp [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Vividnightmare [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ajit Pai [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# freakintiger [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nerubian Squirrel [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Galey92 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# NigerianScammer [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Finger [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# lameboat [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Beriath [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# candiceb [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Renmaru [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# CunardLiner [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# wredniak2003 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Real [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# AnzaTheHuntress [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Gnomerdoom [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# pannta [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# De4thGoD [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Helix [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Babs Le Grand [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ice fuckers [346110, 346900, 440900, 231430, 363970, 214950, 226860, 316010, 48700, 440]
# Synfidie [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Taco-Tom [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Riki [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# AmadeusFrankenstein [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dr.Tesla [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Catnapper [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Suicide Ride [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# alex.n.gregory [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# extra jellyfish [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# High Flyer [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mr.Zone [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Retarδed βαηαηα [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Xavier Rez [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# EGOIST [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# regalbeagle45 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Jay §oyer [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# k1Ng [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# TheWidestMule [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# StillDreams [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# OWN-ED [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# bobby-Ka [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tokair [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Omae wa mou shindeiru [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Nose [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Neo Blitz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SLAYER [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# gjames812 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Teviko604 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# tl;dr [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SlitThroat339 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# OutlookGRiM [346110, 346900, 440900, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# Æðelwine [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Enki [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ChickeNuke [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Marilyn Monro [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Chuby Chuby The Chub Of Chubs [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Floyd! [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# VIETNAMIBALZSAM [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Square Boi [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# iNoOne101 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ☠๖HoldynMahGroin☠ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Awesome Weegee👌 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Xieso [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Kali_Namir [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ryuu [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# twitch.tv/BRAHNtheGOD [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# OliviaInMyBed [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Fasterthanlight [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# InnerInsomniaConflict [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Blank slate [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Carl Johnson [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Argh! [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# dunk CSGO500 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Daneno [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Minoris [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Grazen [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# bluepidgen [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Toltage [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SinisterSpektre [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# TechMatt [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hatzz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# P. Ramos [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Serpens [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# LockeProposal [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Red Fire [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mal [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# VGR_Okami [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# NimrodX [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Venom_Overlord© [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# noot [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# pReaCHer [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Child Labor [346110, 346900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# BoomBoxOi [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Steph Doble S [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Devi Dee [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# XxX_420pUsSy_SlAyEr69_XxX [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# JDtG [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# gunsage [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# detar67 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# HoneY NuT CheeriOS [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Blue [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# cocamo joe [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Pakkidis [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# mike cesara [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# DCxDemo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Breezar_ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Brutal Assmaster [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Baloq - 353 days until Christmas [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# STEVEN AGEVER [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# VrisKris [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Yspeak137 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mindless [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Kamin [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dank Memes [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [OPSKINS] Bot #4267 [346110, 346900, 440900, 231430, 363970, 214950, 226860, 316010, 48700, 440]
# Nicy-V [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Frozen_Sherbet [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Buick [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Atheenae [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# flaky [346110, 346900, 440900, 231430, 363970, 214950, 226860, 316010, 48700, 440]
# Minax [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Arvalian [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ninja_Clicks [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Fein [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ...
# YesLordGaben [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# DJQuackQuack [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# DevX [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ZzMechinaPorc [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Kraila [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# RR.Domas [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ju1i3 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ege [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Earnest Frankson [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# GRIND LIKE NONE OTHER [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Affermanis [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Twistedsteele [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# aliencube [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# KirkWS [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Will o' the wisp [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Lil' Puggy Vert [346110, 346900, 440900, 231430, 363970, 214950, 226860, 316010, 48700, 440]
# iPoKINg [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# sit down [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dr. Jimcy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# catbug33 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# sn4ck [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tosha [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ｄｒａｓｃｕｓ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# spacemuppet [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# FinnishAssburger [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# K4RM3L ^_^ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# マリアナの栄光 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# higgimonster [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Rakoonial [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# har [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 48700, 440]
# MrMorton [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SodaSeven [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# MFC-03 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tangerita [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dr. Niles Crane [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ColdChimo [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# OG Lit Fam Squad Dab 💯 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Adderall [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Insignus [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# hakister [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Cdub [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Swiftkiller [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mystic [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Liam, Danger Liam [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [25th] NorthernWarr [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# dat boi [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 440]
# grif52 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 𝓔𝓽𝓱𝓪𝓷 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Tiger lily [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Zaotron [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# SAV1OUR [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# worthlesstangent [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Gizmo_RA2 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# JPenguin51 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Pro Ace [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Xeno_Amess [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# 🌱 Cenlee da Gre3n Boi [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Pennywise [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# R3DRuM.CDN [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Minato Arisato [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# iQ !SuRIM [346110, 346900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# Rome [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# bardie [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# BostonKingKush [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ZDonkulous [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Gone Senate [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Fitzgerald the Evil G [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Inquisitive Geist [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# dave-bach [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# h0llywood [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ohhh you touch my tralala [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mechanite [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ♛MohBlagd♛ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# lu. [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# TheLordOfTheAshes [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Dylveryn Maiteris [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# WhiteHead ツ® [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# MeaslyTripod [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# KempoMan [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# clanss [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Chopped [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Майкати е от мъжки пол :) [346110, 346900, 440900, 231430, 4000, 214950, 226860, 316010, 48700, 440]
# ✪ Ren | cs.money [346110, 346900, 440900, 231430, 363970, 214950, 226860, 316010, 48700, 440]
# '# GuillotinE BR [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Big Bad Brian [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# iSpooky [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# matty1monopoly [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Yasty [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sun-Sensei [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# myrudehand [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# chaoticyle [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Jonathon Hills [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# charlesahiggins [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Narshero [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# harry_db [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# chiefszl95 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# infinitepush [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# junebug [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Flock Stepper #26 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# withche07 (Mert) 🇹🇷 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mp Jens (>N<) [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ThreeLittleNinjas [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# [DP] Stream Daddy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Implode22 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# UncleFather [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Roger Cheeto [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Slaytronic [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Aether Foundation Employee [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# kickass2302 [346110, 346900, 440900, 231430, 4000, 214950, 226860, 316010, 48700, 440]
# dewbasaur [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# mista_chicken [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hellcat JZ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# FeelsBadMan [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# BlackHawk1159 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Gosumania [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Foxtrott [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# yanivfur3 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# RealFlub [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Silent Hunter UK [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# WalshY [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Airballer_hk [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# LegendaryJed [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# shughes26 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Polishhammer83 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Moz1La [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# spikescub [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# VIN_CHANGEZI [346110, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700, 440]
# spito [346110, 346900, 440900, 231430, 363970, 214950, 226860, 316010, 48700, 440]
# Spazzy321456 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Bird Person [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# awakenedheathen [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hockstetter [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Incipit SISSY 10 MY CAT!!!!! [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# IceBlitz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Ki77BiLL [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# MrGhost [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Chubbyme [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# AwesomeMorpheus [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# NicKirito [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# CaLL_ME_YoUr_MaJeSTy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# gerald. upgradecsgo.com [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# speveril [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Pen Island [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# <DP> James Havok [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# YakumoSecluded [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# FOXOOK [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Hexelf [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# GuyBanks [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Crad JJ Binks [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# IndianIlluminati [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Death2Sam [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ~Whimsy~ [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Svůdník [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Syrah「✔」 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# TImBuntU [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# ✪ LoweBoy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# battlecat [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Halcor - Hymn [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Zoid [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Sykey [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# jcolts23 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# OverLordGoldDragon [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Worm [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Donard [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Koz [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# darkdragon735 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Antimouse [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Juicy Ranger | Skinhub.com [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Shadys Back [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Appranax [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Glaxy [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Lace [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Smack [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Mighty Lopez [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Task Force 131 [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# the festive gun spinnin' cat man [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# shizoID °_̯͡° [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]
# Erixes [346110, 346900, 440900, 231430, 363970, 4000, 214950, 226860, 316010, 48700]

# %%
def recomend_games_for_user( username  ):
    
    return top_n[username]

# %%
recomend_games_for_user( 'S-Zachel' )
# Out:
# [(346110, 0.9237605965808111),
#  (346900, 0.9120861331317033),
#  (440900, 0.904827413142782),
#  (231430, 0.8997169062284731),
#  (363970, 0.8964866480534623),
#  (4000, 0.8955804189012952),
#  (214950, 0.8906655333454503),
#  (226860, 0.8893000594882192),
#  (316010, 0.8868024043135004),
#  (48700, 0.8855440916283479)]

# %%
recomend_games_for_user( 'Tord' )
# Out:
# [(346110, 0.937597961445493),
#  (346900, 0.9259234979963853),
#  (440900, 0.9186647780074642),
#  (231430, 0.9135542710931551),
#  (363970, 0.9103240129181442),
#  (4000, 0.9094177837659773),
#  (214950, 0.9045028982101323),
#  (226860, 0.9031374243529012),
#  (316010, 0.9006397691781824),
#  (48700, 0.8993814564930299)]

# %% [markdown]
# ## Ejercicio 3 - Sistema de Recomendación Basado en Juegos
#
# Similar al caso anterior, con la diferencia de que este sistema espera como entrada el nombre de un juego y devuelve una lista de juegos similares. El sistema deberá estar programado en base a información de contenido de los juegos (i.e. filtrado basado en contenido o sistema híbrido).

# %%
# Completa
